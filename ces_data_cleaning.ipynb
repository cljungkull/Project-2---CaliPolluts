# %%
import pandas as pd
import numpy as np

# %%
ces = pd.read_csv("Resources/ces_data.csv")

# %%
ces.head()
# Out:
#    Census Tract  Total Population California County    ZIP Nearby City  \
# 0    6019001100              3174           Fresno   93706      Fresno
# 1    6071001600              6133    San Bernardino  91761     Ontario
# 2    6019000200              3167           Fresno   93706      Fresno
# 3    6077000801              6692       San Joaquin  95203    Stockton
# 4    6019001500              2206           Fresno   93725      Fresno
#
#     Longitude   Latitude  CES 3.0 Score   CES 3.0 Percentile  \
# 0 -119.781696  36.709695          94.09               100.00
# 1 -117.618013  34.057780          90.68                99.99
# 2 -119.805504  36.735491          85.97                99.97
# 3 -121.314524  37.940517          82.49                99.96
# 4 -119.717843  36.681600          82.03                99.95
#
#   CES 3.0 \nPercentile Range  ... Linguistic Isolation Pctl  Poverty  \
# 0   95-100% (highest scores)  ...                     77.51     76.3
# ...

# %%
ces = ces[["Census Tract", "Total Population", "California County", "ZIP", "Nearby City", "Longitude", 
           "Latitude", "Traffic", "Traffic Pctl", "Pollution Burden", "Pollution Burden Score", 
           "Pollution Burden Pctl", "Asthma", "Asthma Pctl", "Poverty", "Poverty Pctl"]]

# %%
ces.to_csv('Resources/clean_ces_v1.csv', header=True)
